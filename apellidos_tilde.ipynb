# %%
# Conversor de apellidos todo en mayúsculas sin tildes a apellidos solo con la primera letra en mayúsucula

with open('/Users/beatrizbustos/Documents/MiNLP/apellidos_ine_mayusculas.txt', 'r') as f: 
    text = f.read()
    text = text.lower()
    words = text.split('\n')
    #print(words)
    capitalized_words = []
    for word in words:
        title_case_word = word[0].upper() + word[1:]
        capitalized_words.append(title_case_word)
    output = ' '.join(capitalized_words)
    output = output.replace(" ","\n")
f = open('/Users/beatrizbustos/Documents/MiNLP/apellidos_ine_title.txt', 'w')
f.write(output)
f.close()

# %%
#Lista de apellidos en mayúsculas. 

f = open('/Users/beatrizbustos/Documents/MiNLP/apellidos_ine_mayusculas_title_copia.txt', 'r')
text = f.read()
words = text.split('\n')
#print(words)

char = 'Á'
char2 = 'À'
char3 = 'Â'
charA = "á"
charB = "à"
charC = "â"

char4 = 'É'
char5 = 'È'
char6 = 'Ê'
charD = "é"
charE = "è"
charF = "ê"

char7 = 'Í'
char8 = 'Ì'
char9 = 'Î'
charG = "í"
charH = "ì"
charI = "î"

char10 = 'Ó'
char11 = 'Ò'
char12 = 'Ô'
charJ = "ó"
charK = "ò"
charL = "ô"

char13 = 'Ú'
char14 = 'Ù'
char15 = 'Û'
charM = "ú"
charN = "ù"
charO = "û"


# Archivo para guardar todas las posibles tildes de cada apellido

f = open('/Users/beatrizbustos/Documents/MiNLP/apellidos_ine_mayusculas_title_copia_tildes.txt', 'w')

# Scritp para crear todas las posibles tildes de cada apellido. 

for word in words:
    #print("word", word)
    lista1 = [m.start() for m in re.finditer(r"A",word)] #Obtenemos todas las posiciones de la A del apellido
    listaA = [m.start() for m in re.finditer(r"a",word)]
    #print (lista)
    for pos in lista1:
        str_lst = list(word)
        str_lst[pos] = char
        str1 = ''.join(str_lst)
        #print(str1)
        f.write(str1 + "\n")

        str_lst[pos] = char2
        str2 = ''.join(str_lst)
        #print(str2)
        f.write(str2 + "\n")

        str_lst[pos] = char3
        str3 = ''.join(str_lst)
        #print(str3)
        f.write(str3 + "\n")
        
    for pos in listaA:
        str_lst = list(word)
        str_lst[pos] = charA
        strA = ''.join(str_lst)
        #print(str1)
        f.write(strA + "\n")

        str_lst[pos] = charB
        strB = ''.join(str_lst)
        #print(str2)
        f.write(strB + "\n")

        str_lst[pos] = charC
        strC = ''.join(str_lst)
        #print(str3)
        f.write(strC + "\n")

#lista = [m.start() for m in re.finditer(r"E",s)]

#print (lista)

#for word in words:
    #print("word", word)
    lista2 = [m.start() for m in re.finditer(r"E",word)]
    listaB = [m.start() for m in re.finditer(r"e",word)]
    #print (lista)
    for pos in lista2:
        str_lst = list(word)
        str_lst[pos] = char4
        str4 = ''.join(str_lst)
        #print(str4)
        f.write(str4 + "\n")

        str_lst[pos] = char5
        str5 = ''.join(str_lst)
        #print(str5)
        f.write(str5 + "\n")

        str_lst[pos] = char6
        str6 = ''.join(str_lst)
        #print(str6)
        f.write(str6 + "\n")
        
    for pos in listaB:
        str_lst = list(word)
        str_lst[pos] = charD
        strD = ''.join(str_lst)
        #print(str4)
        f.write(strD + "\n")

        str_lst[pos] = charE
        strE = ''.join(str_lst)
        #print(str5)
        f.write(strE + "\n")

        str_lst[pos] = charF
        strF = ''.join(str_lst)
        #print(str6)
        f.write(strF + "\n")
    
#lista = [m.start() for m in re.finditer(r"I",s)]

#print (lista)

#for word in words:
    print("word", word)
    lista3 = [m.start() for m in re.finditer(r"I",word)]
    listaC = [m.start() for m in re.finditer(r"i",word)]
    #print (lista)
    for pos in lista3:
        str_lst = list(word)
        str_lst[pos] = char7
        str7 = ''.join(str_lst)
        #print(str7)
        f.write(str7 + "\n")

        str_lst[pos] = char8
        str8 = ''.join(str_lst)
        #print(str8)
        f.write(str8 + "\n")

        str_lst[pos] = char9
        str9 = ''.join(str_lst)
        #print(str9)
        f.write(str9 + "\n")
        
    for pos in listaC:
        str_lst = list(word)
        str_lst[pos] = charG
        strG = ''.join(str_lst)
        #print(str7)
        f.write(strG + "\n")

        str_lst[pos] = charH
        strH = ''.join(str_lst)
        #print(str8)
        f.write(strH + "\n")

        str_lst[pos] = charI
        strI = ''.join(str_lst)
        #print(str9)
        f.write(strI + "\n")
    
#lista = [m.start() for m in re.finditer(r"O",s)]

#print (lista)
#for word in words:
    #print("word", word)
    lista4 = [m.start() for m in re.finditer(r"O",word)]
    listaD = [m.start() for m in re.finditer(r"o",word)]
    #print (lista)
    for pos in lista4:
        str_lst = list(word)
        str_lst[pos] = char10
        str10 = ''.join(str_lst)
        #print(str10)
        f.write(str10 + "\n")

        str_lst[pos] = char11
        str11 = ''.join(str_lst)
        #print(str11)
        f.write(str11 + "\n")

        str_lst[pos] = char12
        str12 = ''.join(str_lst)
        #print(str12)
        f.write(str12 + "\n")
        
    for pos in listaD:
        str_lst = list(word)
        str_lst[pos] = charJ
        strJ = ''.join(str_lst)
        #print(str10)
        f.write(strJ + "\n")

        str_lst[pos] = charK
        strK = ''.join(str_lst)
        #print(str11)
        f.write(strK + "\n")

        str_lst[pos] = charL
        strL = ''.join(str_lst)
        #print(str12)
        f.write(strL + "\n")
    
#lista = [m.start() for m in re.finditer(r"U",s)]

#print (lista)    
#for word in words:
    #print("word", word)
    lista5 = [m.start() for m in re.finditer(r"U",word)]
    listaE = [m.start() for m in re.finditer(r"u",word)]
    #print (lista5)
    #print (listaE)
    for pos in lista5:
        str_lst = list(word)
        #print(str_lst)
        str_lst[pos] = char13
        #print(char13)
        str13 = ''.join(str_lst)
        #print(str13)
        f.write(str13 + "\n")

        str_lst[pos] = char14
        str14 = ''.join(str_lst)
        #print(str14)
        f.write(str14 + "\n")

        str_lst[pos] = char15
        str15 = ''.join(str_lst)
        #print(str15)
        f.write(str15 + "\n")
        
    for pos in listaE:
        str_lst = list(word)
        str_lst[pos] = charM
        strM = ''.join(str_lst)
        #print(strM)
        f.write(strM + "\n")

        str_lst[pos] = charN
        strN = ''.join(str_lst)
        #print(strN)
        f.write(strN + "\n")

        str_lst[pos] = charO
        strO = ''.join(str_lst)
        #print(strO)
        f.write(strO + "\n")
# Out:
# word ABADIAS
# word Abadias
# word ABADIE
# word Abadie
# word ABADIN
# word Abadin
# word ABAKHTI
# word Abakhti
# word ABALDE
# word Abalde
# word ABAN
# word Aban
# word ABARQUERO
# word Abarquero
# word ABAS
# word Abas
# word ABASCAL
# word Abascal
# word ABBASSI
# word Abbassi
# word ABDALLA
# word Abdalla
# word ABDOU
# word Abdou
# word ABDOUN
# word Abdoun
# word ABELAIRAS
# word Abelairas
# word ABELLAN
# word Abellan
# word ABESO
# word Abeso
# word ABETE
# word Abete
# word ABLANEDO
# word Ablanedo
# word ABOUFARAS
# word Aboufaras
# word ABRANTES
# word Abrantes
# word ABRIO
# word Abrio
# word ABU
# word Abu
# word ABUBAKAR
# word Abubakar
# word ABUCHA
# word Abucha
# word ACAL
# word Acal
# word ACEITUNO
# word Aceituno
# word ACEMEL
# word Acemel
# word ACEREDA
# word Acereda
# word ACHALANDABASO
# word Achalandabaso
# word ACHIG
# word Achig
# word ACHON
# word Achon
# word ACIEN
# word Acien
# word ACIN
# word Acin
# word ACITORES
# word Acitores
# word ADA
# ...

# %%
#Borradores

import re

s = "CARAMAZANAIOEU"
char = 'Á'
char2 = 'À'
char3 = 'Â'

char4 = 'É'
char5 = 'È'
char6 = 'Ê'

char7 = 'Í'
char8 = 'Ì'
char9 = 'Î'

char10 = 'Ó'
char11 = 'Ò'
char12 = 'Ô'

char13 = 'Ú'
char14 = 'Ù'
char15 = 'Û'



lista = [m.start() for m in re.finditer(r"A",s)]

print (lista)

for pos in lista:
    str_lst = list(s)
    str_lst[pos] = char
    str1 = ''.join(str_lst)
    print(str1)
    
    str_lst[pos] = char2
    str2 = ''.join(str_lst)
    print(str2)
    
    str_lst[pos] = char3
    str3 = ''.join(str_lst)
    print(str3)

lista = [m.start() for m in re.finditer(r"E",s)]

print (lista)
for pos in lista:
    str_lst = list(s)
    str_lst[pos] = char4
    str4 = ''.join(str_lst)
    print(str4)
    
    str_lst[pos] = char5
    str5 = ''.join(str_lst)
    print(str5)
    
    str_lst[pos] = char6
    str6 = ''.join(str_lst)
    print(str6)
    
lista = [m.start() for m in re.finditer(r"I",s)]

print (lista)    
for pos in lista:
    str_lst = list(s)
    str_lst[pos] = char7
    str7 = ''.join(str_lst)
    print(str7)
    
    str_lst[pos] = char8
    str8 = ''.join(str_lst)
    print(str8)
    
    str_lst[pos] = char9
    str9 = ''.join(str_lst)
    print(str9)
    
lista = [m.start() for m in re.finditer(r"O",s)]

print (lista)    
for pos in lista:
    str_lst = list(s)
    str_lst[pos] = char10
    str10 = ''.join(str_lst)
    print(str10)
    
    str_lst[pos] = char11
    str11 = ''.join(str_lst)
    print(str11)
    
    str_lst[pos] = char11
    str11 = ''.join(str_lst)
    print(str11)
    
lista = [m.start() for m in re.finditer(r"U",s)]

print (lista)    
for pos in lista:
    str_lst = list(s)
    str_lst[pos] = char12
    str12 = ''.join(str_lst)
    print(str12)
    
    str_lst[pos] = char13
    str13 = ''.join(str_lst)
    print(str13)
    
    str_lst[pos] = char14
    str14 = ''.join(str_lst)
    print(str14)

# %%
str1 = 'This string contains lots of semi colons ;;;;'
pos = -1
char = ':'

# convert the string to a list
str_lst = list (str1)

#assign the replacing character
str_lst[pos] = char

# convert list back to string
str1 = ''.join(str_lst)

print(str1)

# %%
s = "CARAMAZANAIOEU"
[m.start() for m in re.finditer(r"E",s)]
# Out:
# [12]

# %%
s = "CARAMAZANAIOEU"
[m.start() for m in re.finditer(r"I",s)]
# Out:
# [10]

# %%
s = "CARAMAZANAIOEU"
[m.start() for m in re.finditer(r"O",s)]
# Out:
# [11]

# %%
programming_language = "Python"

programming_language_list = list(programming_language)

print(programming_language_list)
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
text = "they're bill's friends from the UK"
words = text.split('\n')
print(words)
capitalized_words = []
for word in words:
    title_case_word = word[0].upper() + word[1:]
    capitalized_words.append(title_case_word)
output = ' '.join(capitalized_words)
print(output)
# Out:
# ["they're", "bill's", 'friends', 'from', 'the', 'UK']
# They're Bill's Friends From The UK

# %%
with open('/Users/beatrizbustos/Documents/MiNLP/apellidos_ine.txt', 'r') as f: 
    text = f.read() 
 
text = text.lower()

# %%
h = "HOLA"
print(type(h))


print(h.lower())
# Out:
# <class 'str'>
# hola

# %%
file = r'/Users/beatrizbustos/Documents/MiNLP/apellidos_ine.txt'

# %%
print(file)
# Out:
# /Users/beatrizbustos/Documents/MiNLP/apellidos_ine.txt

# %%
with open('/Users/beatrizbustos/Documents/MiNLP/apellidos_ine.txt') as f:
    lines = f.readlines()
